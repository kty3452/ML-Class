# %% [markdown]
# <a href="https://colab.research.google.com/github/kty3452/ML-Class/blob/main/HumanActivityResNet_BiLSTM_Attention.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, random, numpy as np, pandas as pd
from typing import Tuple, Dict, Literal
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import StratifiedGroupKFold

# -------------------------------
# Reproducibility
# -------------------------------
SEED = 42
random.seed(SEED); np.random.seed(SEED); tf.random.set_seed(SEED)

# -------------------------------
# Data path
# -------------------------------
DATA_ROOT = "/content/drive/MyDrive/ML_Class"  # ← 필요 시 수정

# 로드 순서 (9채널)
SIGNAL_ORDER = [
    "total_acc_x","total_acc_y","total_acc_z",
    "body_acc_x","body_acc_y","body_acc_z",
    "body_gyro_x","body_gyro_y","body_gyro_z",
]

# -------------------------------
# Loading
# -------------------------------
def _load_group_xy(root: str, group: str):
    base = os.path.join(root, group, "Inertial Signals")
    X = np.dstack([
        pd.read_csv(os.path.join(base, f"{n}_{group}.txt"), sep=r"\s+", header=None).values
        for n in SIGNAL_ORDER
    ]).astype("float32")                                  # (N, 128, 9)
    y = pd.read_csv(os.path.join(root, group, f"y_{group}.txt"), sep=r"\s+", header=None)\
          .values.squeeze().astype("int32") - 1           # 0..5
    subs = pd.read_csv(os.path.join(root, group, f"subject_{group}.txt"), sep=r"\s+", header=None)\
             .values.squeeze().astype("int32")            # subject id
    return X, y, subs

def load_uci_har(root: str):
    Xtr, ytr, sub_tr = _load_group_xy(root, "train")
    Xte, yte, sub_te = _load_group_xy(root, "test")
    return Xtr, ytr, sub_tr, Xte, yte, sub_te

# %%
# -------------------------------
# Utilities
# -------------------------------
def split_to_branches(X: np.ndarray) -> Dict[str, np.ndarray]:
    # X: (N, 128, 9) → 3분기
    total = X[:, :, 0:3]
    body  = X[:, :, 3:6]
    gyro  = X[:, :, 6:9]
    return {"in_body": body, "in_gyro": gyro, "in_total": total}

def instance_norm(X: np.ndarray, eps: float = 1e-6) -> np.ndarray:
    # per-sample per-feature (time-dim 기준)
    mu = X.mean(axis=1, keepdims=True)
    sd = X.std(axis=1, keepdims=True) + eps
    return (X - mu) / sd

def subject_norm(X: np.ndarray, subs: np.ndarray, eps: float = 1e-6) -> np.ndarray:
    """subject-wise μ/σ 정규화 (선택 사항)"""
    Xn = np.empty_like(X)
    subs = np.asarray(subs).reshape(-1)
    for sid in np.unique(subs):
        m = (subs == sid)
        mu = X[m].mean(axis=(0,1), keepdims=True)
        sd = X[m].std(axis=(0,1),  keepdims=True) + eps
        Xn[m] = (X[m] - mu) / sd
    return Xn

def subject_wise_masks(subs: np.ndarray, val_ratio: float = 0.1, seed: int = 42):
    """subject-wise split을 위한 boolean mask 반환 (train_mask, val_mask)"""
    subs = np.asarray(subs).reshape(-1)
    uniq = np.unique(subs)
    rng = np.random.default_rng(seed)
    n_val = max(1, int(len(uniq) * val_ratio))
    val_subs = rng.choice(uniq, size=n_val, replace=False)
    train_mask = ~np.isin(subs, val_subs)
    val_mask   =  np.isin(subs, val_subs)
    return train_mask, val_mask, np.sort(val_subs)

# %%
# -------------------------------
# Model parts
# -------------------------------
def res_bilstm_block(x, units: int, dropout: float = 0.3, name: str | None = None):
    proj = layers.Conv1D(2*units, 1, padding="same", name=f"{name}_proj")(x)
    proj = layers.BatchNormalization(name=f"{name}_proj_bn")(proj)

    y = layers.Bidirectional(layers.LSTM(units, return_sequences=True), name=f"{name}_bilstm")(x)
    y = layers.BatchNormalization(name=f"{name}_bn")(y)
    y = layers.Dropout(dropout, name=f"{name}_drop")(y)

    out = layers.Add(name=f"{name}_add")([proj, y])
    return layers.Activation("relu", name=f"{name}_relu")(out)

class TemporalAdditiveAttention(layers.Layer):
    """x: (B, T, C) → (context(B, C), attn(B, T, 1))"""
    def __init__(self, units=128, **kw):
        super().__init__(**kw)
        self.d1 = layers.Dense(units, activation="tanh")
        self.d2 = layers.Dense(1)
        self.sm = layers.Softmax(axis=1)
    def call(self, x):
        e = self.d2(self.d1(x))  # (B,T,1)
        a = self.sm(e)           # (B,T,1)
        ctx = tf.reduce_sum(a * x, axis=1)  # (B,C)
        return ctx, a

def se_block(x, ratio=8, name=None):
    c = x.shape[-1]
    s = layers.GlobalAveragePooling1D(name=f"{name}_gap")(x)
    s = layers.Dense(max(c // ratio, 8), activation="relu")(s)
    s = layers.Dense(c, activation="sigmoid")(s)
    s = layers.Reshape((1, c))(s)
    return layers.Multiply()([x, s])

# %%
# -------------------------------
# Builders
# -------------------------------
def build_resbilstm_baseline(shape=(128,3), num_classes=6):
    def branch(inp, n):
        z = res_bilstm_block(inp, 128, 0.3, f"{n}_b1")
        z = res_bilstm_block(z, 128, 0.3, f"{n}_b2")
        return layers.GlobalAveragePooling1D(name=f"{n}_gap")(z)
    in_body  = layers.Input(shape=shape, name="in_body")
    in_gyro  = layers.Input(shape=shape, name="in_gyro")
    in_total = layers.Input(shape=shape, name="in_total")
    merged = layers.Concatenate(name="concat_vec")([branch(in_body,"body"),
                                                    branch(in_gyro,"gyro"),
                                                    branch(in_total,"total")])
    x = layers.Dense(256, activation="relu")(merged)
    x = layers.Dropout(0.5)(x)
    out = layers.Dense(num_classes, activation="softmax", name="pred")(x)
    return keras.Model([in_body, in_gyro, in_total], out, name="ResBLSTM_baseline")

def build_resbilstm_with_attention(shape=(128,3), num_classes=6):
    def branch_seq(inp, n):
        z = res_bilstm_block(inp, 128, 0.3, f"{n}_b1")
        z = res_bilstm_block(z, 128, 0.3, f"{n}_b2")
        return z
    in_body  = layers.Input(shape=shape, name="in_body")
    in_gyro  = layers.Input(shape=shape, name="in_gyro")
    in_total = layers.Input(shape=shape, name="in_total")
    merged_seq = layers.Concatenate(axis=-1, name="concat_seq")([
        branch_seq(in_body, "body"),
        branch_seq(in_gyro, "gyro"),
        branch_seq(in_total, "total")
    ])
    merged_seq = layers.LayerNormalization(name="ln_seq")(merged_seq)
    ctx, attn = TemporalAdditiveAttention(128, name="attn")(merged_seq)
    x = layers.Dropout(0.5)(ctx)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(0.5)(x)
    out = layers.Dense(num_classes, activation="softmax", name="pred")(x)
    return keras.Model([in_body, in_gyro, in_total], out, name="ResBLSTM_attention")

def build_resbilstm_with_attn_and_se(shape=(128,3), num_classes=6):
    def branch_seq(inp, n):
        z = res_bilstm_block(inp, 128, 0.35, f"{n}_b1")
        z = res_bilstm_block(z, 128, 0.35, f"{n}_b2")
        return z
    in_body  = layers.Input(shape=shape, name="in_body")
    in_gyro  = layers.Input(shape=shape, name="in_gyro")
    in_total = layers.Input(shape=shape, name="in_total")
    merged_seq = layers.Concatenate(axis=-1, name="concat_seq")([
        branch_seq(in_body, "body"),
        branch_seq(in_gyro, "gyro"),
        branch_seq(in_total, "total")
    ])
    merged_seq = layers.LayerNormalization(name="ln_seq")(merged_seq)
    merged_seq = se_block(merged_seq, ratio=8, name="se")
    ctx, attn = TemporalAdditiveAttention(128, name="attn")(merged_seq)
    x = layers.Dropout(0.55)(ctx)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.LayerNormalization(name="ln_head")(x)
    x = layers.Dropout(0.55)(x)
    out = layers.Dense(num_classes, activation="softmax", name="pred")(x)
    return keras.Model([in_body, in_gyro, in_total], out, name="ResBLSTM_attn_se")

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import numpy as np

def cross_subject_5fold_eval(
    epochs: int = 60,
    batch: int = 128,
    lr: float = 1e-3,
    data_root: str = DATA_ROOT,
    do_instance_norm: bool = False,
    use_subject_norm: bool = False,
    folds: int = 5,
    seed: int = 42
):
    # ---------- Load all ----------
    Xtr, ytr, sub_tr, Xte, yte, sub_te = load_uci_har(data_root)
    # 전체 합치기 (train/test 구분 무시)
    X_all  = np.concatenate([Xtr, Xte], axis=0)
    y_all  = np.concatenate([ytr, yte], axis=0)
    subs_all = np.concatenate([sub_tr, sub_te], axis=0)

    uniq_subs = np.unique(subs_all)
    print(f"[INFO] Total subjects: {len(uniq_subs)}")

    all_accs, fold_reports = [], []

    # ----- (Subject-Group + Label-Stratified) 5Fold -----
    sgkf_outer = StratifiedGroupKFold(n_splits=folds, shuffle=True, random_state=seed)

    for fold_id, (trainval_idx, test_idx) in enumerate(
            sgkf_outer.split(X_all, y_all, groups=subs_all), start=1):

        # ----- 내부 분할: train/val도 그룹/라벨 균형 -----
        sub_tv = subs_all[trainval_idx]
        y_tv   = y_all[trainval_idx]
        uniq_sub_tv = np.unique(sub_tv)

        # 대략 val subject ~4명 수준(원하면 숫자만 바꿔도 됨)
        n_val_groups = 4
        n_splits_inner = max(2, len(uniq_sub_tv) // n_val_groups)

        sgkf_inner = StratifiedGroupKFold(
            n_splits=n_splits_inner, shuffle=True, random_state=seed + fold_id
        )
        inner_train_rel, inner_val_rel = next(
            sgkf_inner.split(X_all[trainval_idx], y_tv, groups=sub_tv)
        )

        train_idx = trainval_idx[inner_train_rel]
        val_idx   = trainval_idx[inner_val_rel]

        # ---- subject 목록 로그 (형식은 기존과 동일)
        print(f"\n========== Fold {fold_id}/{folds} ==========")
        print("Train subs:", np.sort(np.unique(subs_all[train_idx])).tolist())
        print("Val subs:  ", np.sort(np.unique(subs_all[val_idx])).tolist())
        print("Test subs: ", np.sort(np.unique(subs_all[test_idx])).tolist())

        # 정규화
        if use_subject_norm:
            Xn = subject_norm(X_all, subs_all)
        else:
            Xn = X_all.copy()
            if do_instance_norm:
                Xn = instance_norm(Xn)

        # ---------- 브랜치 분할 & 인덱싱 ----------
        br_all   = split_to_branches(Xn)
        br_train = {k: v[train_idx] for k, v in br_all.items()}
        br_val   = {k: v[val_idx]   for k, v in br_all.items()}
        br_test  = {k: v[test_idx]  for k, v in br_all.items()}
        y_train, y_val, y_test = y_all[train_idx], y_all[val_idx], y_all[test_idx]

        input_shape = br_train["in_body"].shape[1:]
        num_classes = int(y_all.max() + 1)

        # ---------- Model ----------
        model = build_resbilstm_with_attention(input_shape, num_classes)
        model.compile(
            optimizer=keras.optimizers.Adam(learning_rate=lr),
            loss=keras.losses.SparseCategoricalCrossentropy(),
            metrics=["accuracy"]
        )
        cb = [
            keras.callbacks.ReduceLROnPlateau(
                monitor="val_loss", factor=0.5, patience=6, min_lr=1e-6, verbose=0
            ),
            keras.callbacks.EarlyStopping(
                monitor="val_loss", patience=20, restore_best_weights=True, verbose=0
            ),
        ]

        # ---------- Train ----------
        hist = model.fit(
            br_train, y_train,
            validation_data=(br_val, y_val),
            epochs=epochs, batch_size=batch, verbose=1, callbacks=cb
        )

        # ---------- Test ----------
        y_pred = np.argmax(model.predict(br_test, batch_size=batch, verbose=0), axis=1)
        acc = accuracy_score(y_test, y_pred)
        all_accs.append(acc)
        rep = classification_report(y_test, y_pred, digits=4, output_dict=True)
        fold_reports.append(rep)

        print(f"[Fold {fold_id}] Test Accuracy: {acc*100:.2f}%")

    # ---------- Summary ----------
    print("\n========== 5-Fold Summary ==========")
    print(f"Mean Accuracy: {np.mean(all_accs)*100:.2f}% ± {np.std(all_accs)*100:.2f}%")

    return all_accs, fold_reports

# %%
accs, reports = cross_subject_5fold_eval(
    epochs=60, batch=128, lr=1e-3,
    data_root=DATA_ROOT,
    do_instance_norm=False,
    use_subject_norm=True
)
# Out:
# [INFO] Total subjects: 30
#
# ========== Fold 1/5 ==========
# Train subs: [2, 3, 4, 5, 8, 10, 11, 12, 13, 16, 18, 19, 20, 21, 22, 23, 24, 27, 28, 30]
# Val subs:   [1, 7, 9, 15]
# Test subs:  [6, 14, 17, 25, 26, 29]
# Epoch 1/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 29s 234ms/step - accuracy: 0.8125 - loss: 0.5362 - val_accuracy: 0.4666 - val_loss: 3.3573 - learning_rate: 0.0010
# Epoch 2/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 204ms/step - accuracy: 0.9560 - loss: 0.1233 - val_accuracy: 0.4658 - val_loss: 4.1720 - learning_rate: 0.0010
# Epoch 3/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 205ms/step - accuracy: 0.9688 - loss: 0.0848 - val_accuracy: 0.5075 - val_loss: 3.0085 - learning_rate: 0.0010
# Epoch 4/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 206ms/step - accuracy: 0.9700 - loss: 0.0783 - val_accuracy: 0.5578 - val_loss: 2.2233 - learning_rate: 0.0010
# Epoch 5/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 21s 206ms/step - accuracy: 0.9747 - loss: 0.0683 - val_accuracy: 0.7655 - val_loss: 0.8964 - learning_rate: 0.0010
# Epoch 6/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 215ms/step - accuracy: 0.9795 - loss: 0.0514 - val_accuracy: 0.9158 - val_loss: 0.2323 - learning_rate: 0.0010
# Epoch 7/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 206ms/step - accuracy: 0.9831 - loss: 0.0456 - val_accuracy: 0.9072 - val_loss: 0.2856 - learning_rate: 0.0010
# Epoch 8/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 208ms/step - accuracy: 0.9837 - loss: 0.0439 - val_accuracy: 0.9363 - val_loss: 0.1895 - learning_rate: 0.0010
# Epoch 9/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 219ms/step - accuracy: 0.9838 - loss: 0.0392 - val_accuracy: 0.9607 - val_loss: 0.1248 - learning_rate: 0.0010
# Epoch 10/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 207ms/step - accuracy: 0.9856 - loss: 0.0385 - val_accuracy: 0.9504 - val_loss: 0.1338 - learning_rate: 0.0010
# Epoch 11/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 207ms/step - accuracy: 0.9866 - loss: 0.0354 - val_accuracy: 0.9496 - val_loss: 0.1728 - learning_rate: 0.0010
# Epoch 12/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 209ms/step - accuracy: 0.9885 - loss: 0.0322 - val_accuracy: 0.9473 - val_loss: 0.1974 - learning_rate: 0.0010
# Epoch 13/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 214ms/step - accuracy: 0.9846 - loss: 0.0481 - val_accuracy: 0.9528 - val_loss: 0.1562 - learning_rate: 0.0010
# Epoch 14/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 209ms/step - accuracy: 0.9857 - loss: 0.0337 - val_accuracy: 0.9630 - val_loss: 0.1420 - learning_rate: 0.0010
# Epoch 15/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 209ms/step - accuracy: 0.9933 - loss: 0.0228 - val_accuracy: 0.9622 - val_loss: 0.1797 - learning_rate: 0.0010
# Epoch 16/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9905 - loss: 0.0271 - val_accuracy: 0.9520 - val_loss: 0.2227 - learning_rate: 5.0000e-04
# Epoch 17/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9958 - loss: 0.0131 - val_accuracy: 0.9489 - val_loss: 0.3041 - learning_rate: 5.0000e-04
# Epoch 18/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 209ms/step - accuracy: 0.9966 - loss: 0.0089 - val_accuracy: 0.9614 - val_loss: 0.2267 - learning_rate: 5.0000e-04
# Epoch 19/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 209ms/step - accuracy: 0.9972 - loss: 0.0101 - val_accuracy: 0.9654 - val_loss: 0.2064 - learning_rate: 5.0000e-04
# Epoch 20/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9960 - loss: 0.0115 - val_accuracy: 0.9512 - val_loss: 0.3014 - learning_rate: 5.0000e-04
# Epoch 21/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 21s 222ms/step - accuracy: 0.9960 - loss: 0.0101 - val_accuracy: 0.9520 - val_loss: 0.2907 - learning_rate: 5.0000e-04
# Epoch 22/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9962 - loss: 0.0109 - val_accuracy: 0.9567 - val_loss: 0.2636 - learning_rate: 2.5000e-04
# Epoch 23/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9989 - loss: 0.0035 - val_accuracy: 0.9654 - val_loss: 0.2091 - learning_rate: 2.5000e-04
# Epoch 24/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9989 - loss: 0.0032 - val_accuracy: 0.9693 - val_loss: 0.1870 - learning_rate: 2.5000e-04
# Epoch 25/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 21s 209ms/step - accuracy: 0.9995 - loss: 0.0036 - val_accuracy: 0.9677 - val_loss: 0.1959 - learning_rate: 2.5000e-04
# Epoch 26/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 209ms/step - accuracy: 0.9997 - loss: 0.0016 - val_accuracy: 0.9725 - val_loss: 0.1801 - learning_rate: 2.5000e-04
# Epoch 27/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 209ms/step - accuracy: 0.9986 - loss: 0.0039 - val_accuracy: 0.9630 - val_loss: 0.2369 - learning_rate: 2.5000e-04
# Epoch 28/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 209ms/step - accuracy: 0.9984 - loss: 0.0045 - val_accuracy: 0.9740 - val_loss: 0.1535 - learning_rate: 1.2500e-04
# Epoch 29/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9982 - loss: 0.0033 - val_accuracy: 0.9677 - val_loss: 0.2041 - learning_rate: 1.2500e-04
# [Fold 1] Test Accuracy: 97.41%
#
# ========== Fold 2/5 ==========
# Train subs: [1, 3, 4, 9, 13, 14, 16, 17, 18, 19, 20, 21, 22, 23, 25, 26, 27, 28, 29, 30]
# Val subs:   [6, 12, 15, 24]
# Test subs:  [2, 5, 7, 8, 10, 11]
# Epoch 1/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 29s 239ms/step - accuracy: 0.8019 - loss: 0.5989 - val_accuracy: 0.6233 - val_loss: 1.7851 - learning_rate: 0.0010
# Epoch 2/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 209ms/step - accuracy: 0.9543 - loss: 0.1239 - val_accuracy: 0.4476 - val_loss: 3.0811 - learning_rate: 0.0010
# Epoch 3/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 209ms/step - accuracy: 0.9682 - loss: 0.0848 - val_accuracy: 0.5362 - val_loss: 2.2604 - learning_rate: 0.0010
# Epoch 4/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 209ms/step - accuracy: 0.9739 - loss: 0.0651 - val_accuracy: 0.6913 - val_loss: 1.1079 - learning_rate: 0.0010
# Epoch 5/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 209ms/step - accuracy: 0.9703 - loss: 0.0834 - val_accuracy: 0.8043 - val_loss: 0.5551 - learning_rate: 0.0010
# Epoch 6/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.9758 - loss: 0.0587 - val_accuracy: 0.9195 - val_loss: 0.2912 - learning_rate: 0.0010
# Epoch 7/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 211ms/step - accuracy: 0.9827 - loss: 0.0478 - val_accuracy: 0.9468 - val_loss: 0.1203 - learning_rate: 0.0010
# Epoch 8/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.9794 - loss: 0.0527 - val_accuracy: 0.9808 - val_loss: 0.0483 - learning_rate: 0.0010
# Epoch 9/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 209ms/step - accuracy: 0.9896 - loss: 0.0261 - val_accuracy: 0.9808 - val_loss: 0.0627 - learning_rate: 0.0010
# Epoch 10/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.9889 - loss: 0.0316 - val_accuracy: 0.9742 - val_loss: 0.0759 - learning_rate: 0.0010
# Epoch 11/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.9882 - loss: 0.0279 - val_accuracy: 0.9638 - val_loss: 0.1582 - learning_rate: 0.0010
# Epoch 12/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.9835 - loss: 0.0423 - val_accuracy: 0.9468 - val_loss: 0.2268 - learning_rate: 0.0010
# Epoch 13/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.9856 - loss: 0.0391 - val_accuracy: 0.9609 - val_loss: 0.1430 - learning_rate: 0.0010
# Epoch 14/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.9895 - loss: 0.0284 - val_accuracy: 0.9623 - val_loss: 0.1542 - learning_rate: 0.0010
# Epoch 15/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.9854 - loss: 0.0403 - val_accuracy: 0.9668 - val_loss: 0.1341 - learning_rate: 5.0000e-04
# Epoch 16/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.9947 - loss: 0.0110 - val_accuracy: 0.9682 - val_loss: 0.1038 - learning_rate: 5.0000e-04
# Epoch 17/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 211ms/step - accuracy: 0.9970 - loss: 0.0103 - val_accuracy: 0.9838 - val_loss: 0.0585 - learning_rate: 5.0000e-04
# Epoch 18/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.9980 - loss: 0.0080 - val_accuracy: 0.9793 - val_loss: 0.0991 - learning_rate: 5.0000e-04
# Epoch 19/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.9982 - loss: 0.0046 - val_accuracy: 0.9808 - val_loss: 0.1083 - learning_rate: 5.0000e-04
# Epoch 20/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.9984 - loss: 0.0044 - val_accuracy: 0.9771 - val_loss: 0.1153 - learning_rate: 5.0000e-04
# Epoch 21/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.9999 - loss: 0.0016 - val_accuracy: 0.9771 - val_loss: 0.0914 - learning_rate: 2.5000e-04
# Epoch 22/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.9998 - loss: 0.0015 - val_accuracy: 0.9845 - val_loss: 0.0664 - learning_rate: 2.5000e-04
# Epoch 23/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9838 - val_loss: 0.0703 - learning_rate: 2.5000e-04
# Epoch 24/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9786 - val_loss: 0.0861 - learning_rate: 2.5000e-04
# Epoch 25/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9823 - val_loss: 0.0889 - learning_rate: 2.5000e-04
# Epoch 26/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 211ms/step - accuracy: 1.0000 - loss: 4.0629e-04 - val_accuracy: 0.9838 - val_loss: 0.0881 - learning_rate: 2.5000e-04
# Epoch 27/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.9997 - loss: 5.9078e-04 - val_accuracy: 0.9801 - val_loss: 0.1061 - learning_rate: 1.2500e-04
# Epoch 28/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 211ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9808 - val_loss: 0.1003 - learning_rate: 1.2500e-04
# [Fold 2] Test Accuracy: 93.01%
#
# ========== Fold 3/5 ==========
# Train subs: [2, 3, 4, 5, 6, 7, 8, 9, 10, 14, 17, 19, 20, 21, 25, 26, 27, 28, 29, 30]
# Val subs:   [1, 11, 13, 22]
# Test subs:  [12, 15, 16, 18, 23, 24]
# Epoch 1/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 28s 239ms/step - accuracy: 0.7903 - loss: 0.6279 - val_accuracy: 0.5164 - val_loss: 2.6686 - learning_rate: 0.0010
# Epoch 2/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 209ms/step - accuracy: 0.9478 - loss: 0.1347 - val_accuracy: 0.4981 - val_loss: 3.2882 - learning_rate: 0.0010
# Epoch 3/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 209ms/step - accuracy: 0.9673 - loss: 0.0927 - val_accuracy: 0.4836 - val_loss: 3.3774 - learning_rate: 0.0010
# Epoch 4/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9657 - loss: 0.0842 - val_accuracy: 0.6812 - val_loss: 1.2953 - learning_rate: 0.0010
# Epoch 5/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9670 - loss: 0.0796 - val_accuracy: 0.8780 - val_loss: 0.4296 - learning_rate: 0.0010
# Epoch 6/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9746 - loss: 0.0577 - val_accuracy: 0.9413 - val_loss: 0.2273 - learning_rate: 0.0010
# Epoch 7/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 221ms/step - accuracy: 0.9792 - loss: 0.0563 - val_accuracy: 0.9397 - val_loss: 0.1943 - learning_rate: 0.0010
# Epoch 8/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9807 - loss: 0.0546 - val_accuracy: 0.9802 - val_loss: 0.0511 - learning_rate: 0.0010
# Epoch 9/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9784 - loss: 0.0571 - val_accuracy: 0.9794 - val_loss: 0.0598 - learning_rate: 0.0010
# Epoch 10/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9870 - loss: 0.0348 - val_accuracy: 0.9786 - val_loss: 0.0529 - learning_rate: 0.0010
# Epoch 11/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9814 - loss: 0.0489 - val_accuracy: 0.9855 - val_loss: 0.0318 - learning_rate: 0.0010
# Epoch 12/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9859 - loss: 0.0386 - val_accuracy: 0.9939 - val_loss: 0.0244 - learning_rate: 0.0010
# Epoch 13/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9914 - loss: 0.0252 - val_accuracy: 0.9962 - val_loss: 0.0114 - learning_rate: 0.0010
# Epoch 14/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9892 - loss: 0.0249 - val_accuracy: 0.9931 - val_loss: 0.0180 - learning_rate: 0.0010
# Epoch 15/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 20s 209ms/step - accuracy: 0.9924 - loss: 0.0183 - val_accuracy: 0.9916 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 16/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9892 - loss: 0.0286 - val_accuracy: 0.9863 - val_loss: 0.0396 - learning_rate: 0.0010
# Epoch 17/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9832 - loss: 0.0454 - val_accuracy: 0.9954 - val_loss: 0.0107 - learning_rate: 0.0010
# Epoch 18/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9849 - loss: 0.0401 - val_accuracy: 0.9924 - val_loss: 0.0258 - learning_rate: 0.0010
# Epoch 19/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9899 - loss: 0.0294 - val_accuracy: 0.9954 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 20/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9917 - loss: 0.0273 - val_accuracy: 0.9886 - val_loss: 0.0665 - learning_rate: 0.0010
# Epoch 21/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9897 - loss: 0.0285 - val_accuracy: 0.9855 - val_loss: 0.0512 - learning_rate: 0.0010
# Epoch 22/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 209ms/step - accuracy: 0.9910 - loss: 0.0244 - val_accuracy: 0.9962 - val_loss: 0.0066 - learning_rate: 0.0010
# Epoch 23/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9949 - loss: 0.0137 - val_accuracy: 0.9969 - val_loss: 0.0073 - learning_rate: 0.0010
# Epoch 24/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9943 - loss: 0.0168 - val_accuracy: 0.9916 - val_loss: 0.0240 - learning_rate: 0.0010
# Epoch 25/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9908 - loss: 0.0233 - val_accuracy: 0.9939 - val_loss: 0.0318 - learning_rate: 0.0010
# Epoch 26/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9944 - loss: 0.0141 - val_accuracy: 0.9947 - val_loss: 0.0129 - learning_rate: 0.0010
# Epoch 27/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9961 - loss: 0.0134 - val_accuracy: 0.9977 - val_loss: 0.0089 - learning_rate: 0.0010
# Epoch 28/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 20s 209ms/step - accuracy: 0.9957 - loss: 0.0126 - val_accuracy: 0.9939 - val_loss: 0.0164 - learning_rate: 0.0010
# Epoch 29/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9955 - loss: 0.0122 - val_accuracy: 0.9992 - val_loss: 0.0036 - learning_rate: 5.0000e-04
# Epoch 30/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 209ms/step - accuracy: 0.9974 - loss: 0.0067 - val_accuracy: 0.9985 - val_loss: 0.0054 - learning_rate: 5.0000e-04
# Epoch 31/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9988 - loss: 0.0036 - val_accuracy: 0.9947 - val_loss: 0.0161 - learning_rate: 5.0000e-04
# Epoch 32/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9987 - loss: 0.0051 - val_accuracy: 0.9962 - val_loss: 0.0131 - learning_rate: 5.0000e-04
# Epoch 33/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9982 - loss: 0.0051 - val_accuracy: 0.9962 - val_loss: 0.0081 - learning_rate: 5.0000e-04
# Epoch 34/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 20s 209ms/step - accuracy: 0.9997 - loss: 0.0020 - val_accuracy: 0.9977 - val_loss: 0.0058 - learning_rate: 5.0000e-04
# Epoch 35/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9984 - loss: 0.0038 - val_accuracy: 0.9962 - val_loss: 0.0121 - learning_rate: 5.0000e-04
# Epoch 36/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9990 - loss: 0.0027 - val_accuracy: 0.9954 - val_loss: 0.0165 - learning_rate: 2.5000e-04
# Epoch 37/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9994 - loss: 0.0020 - val_accuracy: 0.9969 - val_loss: 0.0131 - learning_rate: 2.5000e-04
# Epoch 38/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9993 - loss: 0.0016 - val_accuracy: 0.9947 - val_loss: 0.0187 - learning_rate: 2.5000e-04
# Epoch 39/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9947 - val_loss: 0.0172 - learning_rate: 2.5000e-04
# Epoch 40/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 208ms/step - accuracy: 1.0000 - loss: 4.0966e-04 - val_accuracy: 0.9954 - val_loss: 0.0169 - learning_rate: 2.5000e-04
# Epoch 41/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9999 - loss: 9.9987e-04 - val_accuracy: 0.9947 - val_loss: 0.0169 - learning_rate: 2.5000e-04
# Epoch 42/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9993 - loss: 0.0014 - val_accuracy: 0.9962 - val_loss: 0.0176 - learning_rate: 1.2500e-04
# Epoch 43/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9999 - loss: 5.3939e-04 - val_accuracy: 0.9954 - val_loss: 0.0174 - learning_rate: 1.2500e-04
# Epoch 44/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 1.0000 - loss: 3.3316e-04 - val_accuracy: 0.9954 - val_loss: 0.0177 - learning_rate: 1.2500e-04
# Epoch 45/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 20s 210ms/step - accuracy: 1.0000 - loss: 2.8208e-04 - val_accuracy: 0.9954 - val_loss: 0.0174 - learning_rate: 1.2500e-04
# Epoch 46/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 209ms/step - accuracy: 1.0000 - loss: 2.1141e-04 - val_accuracy: 0.9954 - val_loss: 0.0173 - learning_rate: 1.2500e-04
# Epoch 47/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9999 - loss: 2.3821e-04 - val_accuracy: 0.9954 - val_loss: 0.0174 - learning_rate: 1.2500e-04
# Epoch 48/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9995 - loss: 8.5948e-04 - val_accuracy: 0.9954 - val_loss: 0.0170 - learning_rate: 6.2500e-05
# Epoch 49/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 1.0000 - loss: 2.6773e-04 - val_accuracy: 0.9954 - val_loss: 0.0168 - learning_rate: 6.2500e-05
# [Fold 3] Test Accuracy: 97.94%
#
# ========== Fold 4/5 ==========
# Train subs: [2, 4, 5, 6, 7, 8, 10, 12, 13, 14, 16, 21, 22, 23, 24, 25, 26, 27, 28, 29]
# Val subs:   [11, 15, 17, 18]
# Test subs:  [1, 3, 9, 19, 20, 30]
# Epoch 1/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 31s 243ms/step - accuracy: 0.7992 - loss: 0.5676 - val_accuracy: 0.4935 - val_loss: 2.3060 - learning_rate: 0.0010
# Epoch 2/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9488 - loss: 0.1382 - val_accuracy: 0.4731 - val_loss: 3.1279 - learning_rate: 0.0010
# Epoch 3/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9597 - loss: 0.1090 - val_accuracy: 0.5589 - val_loss: 2.0200 - learning_rate: 0.0010
# Epoch 4/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9707 - loss: 0.0785 - val_accuracy: 0.6584 - val_loss: 1.3816 - learning_rate: 0.0010
# Epoch 5/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9773 - loss: 0.0665 - val_accuracy: 0.9215 - val_loss: 0.3048 - learning_rate: 0.0010
# Epoch 6/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 212ms/step - accuracy: 0.9728 - loss: 0.0835 - val_accuracy: 0.9826 - val_loss: 0.0795 - learning_rate: 0.0010
# Epoch 7/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9764 - loss: 0.0747 - val_accuracy: 0.9789 - val_loss: 0.0626 - learning_rate: 0.0010
# Epoch 8/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9766 - loss: 0.0569 - val_accuracy: 0.9709 - val_loss: 0.0930 - learning_rate: 0.0010
# Epoch 9/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9811 - loss: 0.0524 - val_accuracy: 0.9608 - val_loss: 0.0846 - learning_rate: 0.0010
# Epoch 10/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 20s 210ms/step - accuracy: 0.9863 - loss: 0.0368 - val_accuracy: 0.9797 - val_loss: 0.0602 - learning_rate: 0.0010
# Epoch 11/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9856 - loss: 0.0386 - val_accuracy: 0.9797 - val_loss: 0.0387 - learning_rate: 0.0010
# Epoch 12/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9861 - loss: 0.0347 - val_accuracy: 0.9906 - val_loss: 0.0213 - learning_rate: 0.0010
# Epoch 13/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9859 - loss: 0.0359 - val_accuracy: 0.9637 - val_loss: 0.1074 - learning_rate: 0.0010
# Epoch 14/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9868 - loss: 0.0364 - val_accuracy: 0.9876 - val_loss: 0.0338 - learning_rate: 0.0010
# Epoch 15/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 212ms/step - accuracy: 0.9877 - loss: 0.0338 - val_accuracy: 0.9811 - val_loss: 0.0484 - learning_rate: 0.0010
# Epoch 16/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9907 - loss: 0.0276 - val_accuracy: 0.9833 - val_loss: 0.0502 - learning_rate: 0.0010
# Epoch 17/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9886 - loss: 0.0272 - val_accuracy: 0.9666 - val_loss: 0.1702 - learning_rate: 0.0010
# Epoch 18/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 21s 210ms/step - accuracy: 0.9891 - loss: 0.0298 - val_accuracy: 0.9593 - val_loss: 0.2955 - learning_rate: 0.0010
# Epoch 19/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9950 - loss: 0.0172 - val_accuracy: 0.9789 - val_loss: 0.0857 - learning_rate: 5.0000e-04
# Epoch 20/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 212ms/step - accuracy: 0.9974 - loss: 0.0087 - val_accuracy: 0.9935 - val_loss: 0.0147 - learning_rate: 5.0000e-04
# Epoch 21/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 20s 210ms/step - accuracy: 0.9971 - loss: 0.0075 - val_accuracy: 0.9920 - val_loss: 0.0175 - learning_rate: 5.0000e-04
# Epoch 22/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9975 - loss: 0.0056 - val_accuracy: 0.9935 - val_loss: 0.0151 - learning_rate: 5.0000e-04
# Epoch 23/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9983 - loss: 0.0055 - val_accuracy: 0.9847 - val_loss: 0.0486 - learning_rate: 5.0000e-04
# Epoch 24/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9974 - loss: 0.0075 - val_accuracy: 0.9767 - val_loss: 0.0711 - learning_rate: 5.0000e-04
# Epoch 25/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9966 - loss: 0.0143 - val_accuracy: 0.9884 - val_loss: 0.0395 - learning_rate: 5.0000e-04
# Epoch 26/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9982 - loss: 0.0057 - val_accuracy: 0.9898 - val_loss: 0.0290 - learning_rate: 5.0000e-04
# Epoch 27/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9986 - loss: 0.0036 - val_accuracy: 0.9927 - val_loss: 0.0219 - learning_rate: 2.5000e-04
# Epoch 28/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9997 - loss: 0.0017 - val_accuracy: 0.9898 - val_loss: 0.0282 - learning_rate: 2.5000e-04
# Epoch 29/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 212ms/step - accuracy: 0.9994 - loss: 0.0020 - val_accuracy: 0.9920 - val_loss: 0.0196 - learning_rate: 2.5000e-04
# Epoch 30/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 1.0000 - loss: 9.1569e-04 - val_accuracy: 0.9906 - val_loss: 0.0233 - learning_rate: 2.5000e-04
# Epoch 31/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9998 - loss: 9.5027e-04 - val_accuracy: 0.9927 - val_loss: 0.0212 - learning_rate: 2.5000e-04
# Epoch 32/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 212ms/step - accuracy: 0.9997 - loss: 7.8587e-04 - val_accuracy: 0.9942 - val_loss: 0.0219 - learning_rate: 2.5000e-04
# Epoch 33/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 212ms/step - accuracy: 0.9994 - loss: 0.0019 - val_accuracy: 0.9920 - val_loss: 0.0247 - learning_rate: 1.2500e-04
# Epoch 34/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9999 - loss: 7.4033e-04 - val_accuracy: 0.9898 - val_loss: 0.0318 - learning_rate: 1.2500e-04
# Epoch 35/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 1.0000 - loss: 3.6026e-04 - val_accuracy: 0.9913 - val_loss: 0.0268 - learning_rate: 1.2500e-04
# Epoch 36/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 1.0000 - loss: 2.8158e-04 - val_accuracy: 0.9927 - val_loss: 0.0246 - learning_rate: 1.2500e-04
# Epoch 37/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 213ms/step - accuracy: 0.9997 - loss: 8.0196e-04 - val_accuracy: 0.9927 - val_loss: 0.0195 - learning_rate: 1.2500e-04
# Epoch 38/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 212ms/step - accuracy: 1.0000 - loss: 4.6919e-04 - val_accuracy: 0.9920 - val_loss: 0.0256 - learning_rate: 1.2500e-04
# Epoch 39/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 1.0000 - loss: 3.2038e-04 - val_accuracy: 0.9920 - val_loss: 0.0264 - learning_rate: 6.2500e-05
# Epoch 40/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 212ms/step - accuracy: 0.9998 - loss: 6.2447e-04 - val_accuracy: 0.9920 - val_loss: 0.0237 - learning_rate: 6.2500e-05
# [Fold 4] Test Accuracy: 97.78%
#
# ========== Fold 5/5 ==========
# Train subs: [1, 2, 3, 5, 6, 8, 9, 10, 12, 14, 15, 16, 17, 18, 19, 24, 25, 26, 29, 30]
# Val subs:   [7, 11, 20, 23]
# Test subs:  [4, 13, 21, 22, 27, 28]
# Epoch 1/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 28s 239ms/step - accuracy: 0.8046 - loss: 0.5272 - val_accuracy: 0.7185 - val_loss: 1.3451 - learning_rate: 0.0010
# Epoch 2/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 209ms/step - accuracy: 0.9505 - loss: 0.1256 - val_accuracy: 0.4267 - val_loss: 3.7186 - learning_rate: 0.0010
# Epoch 3/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 209ms/step - accuracy: 0.9633 - loss: 0.0936 - val_accuracy: 0.6281 - val_loss: 1.5137 - learning_rate: 0.0010
# Epoch 4/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 209ms/step - accuracy: 0.9649 - loss: 0.0921 - val_accuracy: 0.8052 - val_loss: 0.7365 - learning_rate: 0.0010
# Epoch 5/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 21s 209ms/step - accuracy: 0.9703 - loss: 0.0698 - val_accuracy: 0.8881 - val_loss: 0.4056 - learning_rate: 0.0010
# Epoch 6/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9701 - loss: 0.0759 - val_accuracy: 0.9252 - val_loss: 0.2270 - learning_rate: 0.0010
# Epoch 7/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9795 - loss: 0.0516 - val_accuracy: 0.9407 - val_loss: 0.2291 - learning_rate: 0.0010
# Epoch 8/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9770 - loss: 0.0624 - val_accuracy: 0.9563 - val_loss: 0.0916 - learning_rate: 0.0010
# Epoch 9/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 209ms/step - accuracy: 0.9815 - loss: 0.0447 - val_accuracy: 0.9570 - val_loss: 0.1060 - learning_rate: 0.0010
# Epoch 10/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 209ms/step - accuracy: 0.9771 - loss: 0.0560 - val_accuracy: 0.9652 - val_loss: 0.0788 - learning_rate: 0.0010
# Epoch 11/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 209ms/step - accuracy: 0.9832 - loss: 0.0531 - val_accuracy: 0.9593 - val_loss: 0.1024 - learning_rate: 0.0010
# Epoch 12/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9827 - loss: 0.0448 - val_accuracy: 0.9711 - val_loss: 0.0815 - learning_rate: 0.0010
# Epoch 13/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9800 - loss: 0.0504 - val_accuracy: 0.9667 - val_loss: 0.1119 - learning_rate: 0.0010
# Epoch 14/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9888 - loss: 0.0298 - val_accuracy: 0.9778 - val_loss: 0.0876 - learning_rate: 0.0010
# Epoch 15/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9876 - loss: 0.0331 - val_accuracy: 0.9770 - val_loss: 0.0663 - learning_rate: 0.0010
# Epoch 16/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 212ms/step - accuracy: 0.9864 - loss: 0.0392 - val_accuracy: 0.9637 - val_loss: 0.0855 - learning_rate: 0.0010
# Epoch 17/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9874 - loss: 0.0263 - val_accuracy: 0.9704 - val_loss: 0.0806 - learning_rate: 0.0010
# Epoch 18/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 221ms/step - accuracy: 0.9918 - loss: 0.0255 - val_accuracy: 0.9733 - val_loss: 0.1005 - learning_rate: 0.0010
# Epoch 19/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 209ms/step - accuracy: 0.9900 - loss: 0.0277 - val_accuracy: 0.9681 - val_loss: 0.0825 - learning_rate: 0.0010
# Epoch 20/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9896 - loss: 0.0297 - val_accuracy: 0.9652 - val_loss: 0.0976 - learning_rate: 0.0010
# Epoch 21/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9898 - loss: 0.0282 - val_accuracy: 0.9585 - val_loss: 0.1802 - learning_rate: 0.0010
# Epoch 22/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9892 - loss: 0.0269 - val_accuracy: 0.9756 - val_loss: 0.0997 - learning_rate: 5.0000e-04
# Epoch 23/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9943 - loss: 0.0154 - val_accuracy: 0.9585 - val_loss: 0.2049 - learning_rate: 5.0000e-04
# Epoch 24/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 20s 209ms/step - accuracy: 0.9921 - loss: 0.0255 - val_accuracy: 0.9770 - val_loss: 0.0724 - learning_rate: 5.0000e-04
# Epoch 25/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 209ms/step - accuracy: 0.9965 - loss: 0.0079 - val_accuracy: 0.9807 - val_loss: 0.0899 - learning_rate: 5.0000e-04
# Epoch 26/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9966 - loss: 0.0060 - val_accuracy: 0.9770 - val_loss: 0.0909 - learning_rate: 5.0000e-04
# Epoch 27/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9989 - loss: 0.0031 - val_accuracy: 0.9793 - val_loss: 0.0866 - learning_rate: 5.0000e-04
# Epoch 28/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9969 - loss: 0.0105 - val_accuracy: 0.9793 - val_loss: 0.0898 - learning_rate: 2.5000e-04
# Epoch 29/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9982 - loss: 0.0063 - val_accuracy: 0.9800 - val_loss: 0.0971 - learning_rate: 2.5000e-04
# Epoch 30/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9985 - loss: 0.0049 - val_accuracy: 0.9800 - val_loss: 0.0920 - learning_rate: 2.5000e-04
# Epoch 31/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9993 - loss: 0.0025 - val_accuracy: 0.9785 - val_loss: 0.1016 - learning_rate: 2.5000e-04
# Epoch 32/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 21s 211ms/step - accuracy: 0.9986 - loss: 0.0028 - val_accuracy: 0.9778 - val_loss: 0.1113 - learning_rate: 2.5000e-04
# Epoch 33/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9999 - loss: 0.0015 - val_accuracy: 0.9770 - val_loss: 0.1297 - learning_rate: 2.5000e-04
# Epoch 34/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9987 - loss: 0.0024 - val_accuracy: 0.9844 - val_loss: 0.1002 - learning_rate: 1.2500e-04
# Epoch 35/60
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 222ms/step - accuracy: 0.9990 - loss: 0.0020 - val_accuracy: 0.9852 - val_loss: 0.0928 - learning_rate: 1.2500e-04
# [Fold 5] Test Accuracy: 98.92%
#
# ========== 5-Fold Summary ==========
# Mean Accuracy: 97.01% ± 2.06%
